# %%
import pandas as pd

# %%
customers = pd.read_csv('Customers.csv')

# %%
customers.head()
# Out:
#   CustomerID        CustomerName         Region  SignupDate
# 0      C0001    Lawrence Carroll  South America  2022-07-10
# 1      C0002      Elizabeth Lutz           Asia  2022-02-13
# 2      C0003      Michael Rivera  South America  2024-03-07
# 3      C0004  Kathleen Rodriguez  South America  2022-10-09
# 4      C0005         Laura Weber           Asia  2022-08-15

# %%
transactions = pd.read_csv('Transactions.csv')

# %%
products = pd.read_csv('Products.csv')

# %%
# Merge Transactions with Products on ProductID to get product details
df_merged = pd.merge(transactions, products, on='ProductID', how='left')

# %%
#  Merge the result with Customers data on CustomerID
df_merged = pd.merge(df_merged, customers, on='CustomerID', how='left')

# %%
#  Aggregating transaction and product data per customer
customer_data = df_merged.groupby('CustomerID').agg({
    'TotalValue': 'sum',  # Total spending
    'Quantity': 'sum',  # Total quantity bought
    'Region': 'first',  # Assuming each customer belongs to one region
    'SignupDate': 'first',  # Signup year
    'Category': lambda x: x.mode()[0],  # Most common product category
}).reset_index()

# %%
#Normalize the data for similarity calculation
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
customer_data[['TotalValue', 'Quantity']] = scaler.fit_transform(customer_data[['TotalValue', 'Quantity']])

# %%
# Cosine Similarity calculation
from sklearn.metrics.pairwise import cosine_similarity
similarity_matrix = cosine_similarity(customer_data[['TotalValue', 'Quantity']])

# %%
# Function to get top 3 similar customers based on cosine similarity
def get_similar_customers(customer_id, top_n=3):
    if customer_id in customer_data['CustomerID'].values:
        customer_index = customer_data[customer_data['CustomerID'] == customer_id].index[0]
        similarity_scores = similarity_matrix[customer_index]
        similar_indices = similarity_scores.argsort()[::-1][1:top_n+1]  # Exclude the customer itself
        similar_customers = customer_data.iloc[similar_indices]
        return similar_customers[['CustomerID', 'TotalValue', 'Quantity', 'Region']], similarity_scores[similar_indices]
    else:
        return None

# %%
# Creating Lookalike.csv for first 20 customers
lookalike_list = []
for customer_id in customer_data['CustomerID'][:20]:
    similar_customers, similarity_scores = get_similar_customers(customer_id, top_n=3)
    if similar_customers is not None:
        for i in range(len(similar_customers)):
            lookalike_list.append({
                'CustomerID': customer_id,
                'LookalikeCustomerID': similar_customers.iloc[i]['CustomerID'],
                'SimilarityScore': similarity_scores[i]
            })

# %%
lookalike_df = pd.DataFrame(lookalike_list)
#  Export to Lookalike.csv
lookalike_df.to_csv('Lookalike.csv', index=False)

# %%
test_customers = customer_data['CustomerID'][:20]  # First 20 customers
for customer_id in test_customers:
    similar_customers, similarity_scores = get_similar_customers(customer_id, top_n=3)
    if similar_customers is not None:
        print(f"CustomerID: {customer_id}")
        # Use enumerate to get the index within similar_customers
        for i, (idx, row) in enumerate(similar_customers.iterrows()):
            print(f"LookalikeCustomerID: {row['CustomerID']}, SimilarityScore: {similarity_scores[i]}")  # Access using i
        print("-" * 50)
    else:
        print(f"CustomerID {customer_id} not found.\n")
# Out:
# CustomerID: C0001
# LookalikeCustomerID: C0085, SimilarityScore: 0.9999990504724361
# LookalikeCustomerID: C0042, SimilarityScore: 0.9998215747742084
# LookalikeCustomerID: C0089, SimilarityScore: 0.9997850140987701
# --------------------------------------------------
# CustomerID: C0002
# LookalikeCustomerID: C0157, SimilarityScore: 0.9999942410168485
# LookalikeCustomerID: C0166, SimilarityScore: 0.999875010843091
# LookalikeCustomerID: C0029, SimilarityScore: 0.9998254255985104
# --------------------------------------------------
# CustomerID: C0003
# LookalikeCustomerID: C0111, SimilarityScore: 0.9940081095432594
# LookalikeCustomerID: C0160, SimilarityScore: 0.9904545038572361
# LookalikeCustomerID: C0147, SimilarityScore: 0.9876382719212549
# --------------------------------------------------
# CustomerID: C0004
# LookalikeCustomerID: C0162, SimilarityScore: 0.9999999965087093
# LookalikeCustomerID: C0165, SimilarityScore: 0.9999594720114721
# LookalikeCustomerID: C0090, SimilarityScore: 0.9986409558134951
# --------------------------------------------------
# CustomerID: C0005
# LookalikeCustomerID: C0080, SimilarityScore: 0.9999822355480511
# LookalikeCustomerID: C0167, SimilarityScore: 0.9999750393711484
# LookalikeCustomerID: C0177, SimilarityScore: 0.9999281138035957
# --------------------------------------------------
# CustomerID: C0006
# LookalikeCustomerID: C0079, SimilarityScore: 0.9999656845154901
# LookalikeCustomerID: C0117, SimilarityScore: 0.9956703718685657
# LookalikeCustomerID: C0196, SimilarityScore: 0.9903168212584458
# --------------------------------------------------
# CustomerID: C0007
# LookalikeCustomerID: C0146, SimilarityScore: 0.9999895943808703
# LookalikeCustomerID: C0125, SimilarityScore: 0.9998372825489154
# LookalikeCustomerID: C0061, SimilarityScore: 0.9997162141129127
# --------------------------------------------------
# CustomerID: C0008
# LookalikeCustomerID: C0109, SimilarityScore: 0.9998419065580372
# LookalikeCustomerID: C0136, SimilarityScore: 0.9995449075266115
# LookalikeCustomerID: C0124, SimilarityScore: 0.9988501083510457
# --------------------------------------------------
# CustomerID: C0009
# LookalikeCustomerID: C0015, SimilarityScore: 0.9999998280836607
# LookalikeCustomerID: C0131, SimilarityScore: 0.9999969915843525
# LookalikeCustomerID: C0193, SimilarityScore: 0.9999942852290301
# --------------------------------------------------
# CustomerID: C0010
# LookalikeCustomerID: C0176, SimilarityScore: 0.9977495907269391
# LookalikeCustomerID: C0027, SimilarityScore: 0.9933907927482107
# LookalikeCustomerID: C0030, SimilarityScore: 0.9784025791083272
# --------------------------------------------------
# CustomerID: C0011
# LookalikeCustomerID: C0139, SimilarityScore: 0.9995752579210655
# LookalikeCustomerID: C0100, SimilarityScore: 0.9992186065437542
# LookalikeCustomerID: C0023, SimilarityScore: 0.9981601131570049
# --------------------------------------------------
# CustomerID: C0012
# LookalikeCustomerID: C0101, SimilarityScore: 0.999958735499151
# LookalikeCustomerID: C0156, SimilarityScore: 0.9998710212245943
# LookalikeCustomerID: C0093, SimilarityScore: 0.9998427725809736
# --------------------------------------------------
# CustomerID: C0013
# LookalikeCustomerID: C0067, SimilarityScore: 0.9998962934726959
# LookalikeCustomerID: C0138, SimilarityScore: 0.9998109989494287
# LookalikeCustomerID: C0141, SimilarityScore: 0.9997829345234197
# --------------------------------------------------
# CustomerID: C0014
# LookalikeCustomerID: C0192, SimilarityScore: 0.999999195523505
# LookalikeCustomerID: C0159, SimilarityScore: 0.9999990484005253
# LookalikeCustomerID: C0186, SimilarityScore: 0.999979545291725
# --------------------------------------------------
# CustomerID: C0015
# LookalikeCustomerID: C0009, SimilarityScore: 0.9999998280836607
# LookalikeCustomerID: C0131, SimilarityScore: 0.9999982579939216
# LookalikeCustomerID: C0120, SimilarityScore: 0.9999928702070295
# --------------------------------------------------
# CustomerID: C0016
# LookalikeCustomerID: C0154, SimilarityScore: 0.9993683855686599
# LookalikeCustomerID: C0040, SimilarityScore: 0.9960728766406054
# LookalikeCustomerID: C0026, SimilarityScore: 0.993943060754397
# --------------------------------------------------
# CustomerID: C0017
# LookalikeCustomerID: C0075, SimilarityScore: 0.9999997918900845
# LookalikeCustomerID: C0179, SimilarityScore: 0.999792419915155
# LookalikeCustomerID: C0039, SimilarityScore: 0.9997215280460565
# --------------------------------------------------
# CustomerID: C0018
# LookalikeCustomerID: C0045, SimilarityScore: 0.9999974739628396
# LookalikeCustomerID: C0041, SimilarityScore: 0.9997600993045762
# LookalikeCustomerID: C0068, SimilarityScore: 0.999404067327854
# --------------------------------------------------
# CustomerID: C0019
# LookalikeCustomerID: C0142, SimilarityScore: 0.9998871390943337
# LookalikeCustomerID: C0174, SimilarityScore: 0.9998674238866583
# LookalikeCustomerID: C0055, SimilarityScore: 0.9993745857345483
# --------------------------------------------------
# CustomerID: C0020
# LookalikeCustomerID: C0058, SimilarityScore: 0.9999997942980384
# LookalikeCustomerID: C0193, SimilarityScore: 0.999998649644113
# LookalikeCustomerID: C0198, SimilarityScore: 0.9999983115151304
# --------------------------------------------------
